# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({
    "A": [0, -5, 12, -4, 3],
    "B": [12.24, 3.14, 2.71, -3.14, np.nan],
    "C": [0.5, 1.2, 0.3, 1.9, 2.2],
    "D": [2000, np.nan, 1000, 7000, 5000]
})
df
# Out:
#     A      B    C       D
# 0   0  12.24  0.5  2000.0
# 1  -5   3.14  1.2     NaN
# 2  12   2.71  0.3  1000.0
# 3  -4  -3.14  1.9  7000.0
# 4   3    NaN  2.2  5000.0

# %%
df = df.style.hide(axis="index")
df
# Out:
# <style type="text/css">
# </style>
# <table id="T_9ba86">
#   <thead>
#     <tr>
#       <th id="T_9ba86_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9ba86_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_9ba86_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_9ba86_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ba86_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9ba86_row0_col1" class="data row0 col1" >12.240000</td>
#       <td id="T_9ba86_row0_col2" class="data row0 col2" >0.500000</td>
#       <td id="T_9ba86_row0_col3" class="data row0 col3" >2000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row1_col0" class="data row1 col0" >-5</td>
#       <td id="T_9ba86_row1_col1" class="data row1 col1" >3.140000</td>
#       <td id="T_9ba86_row1_col2" class="data row1 col2" >1.200000</td>
#       <td id="T_9ba86_row1_col3" class="data row1 col3" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_9ba86_row2_col1" class="data row2 col1" >2.710000</td>
#       <td id="T_9ba86_row2_col2" class="data row2 col2" >0.300000</td>
#       <td id="T_9ba86_row2_col3" class="data row2 col3" >1000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row3_col0" class="data row3 col0" >-4</td>
#       <td id="T_9ba86_row3_col1" class="data row3 col1" >-3.140000</td>
#       <td id="T_9ba86_row3_col2" class="data row3 col2" >1.900000</td>
#       <td id="T_9ba86_row3_col3" class="data row3 col3" >7000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_9ba86_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_9ba86_row4_col2" class="data row4 col2" >2.200000</td>
#       <td id="T_9ba86_row4_col3" class="data row4 col3" >5000.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9ba86">
#   <thead>
#     <tr>
#       <th id="T_9ba86_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9ba86_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_9ba86_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_9ba86_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ba86_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9ba86_row0_col1" class="data row0 col1" >12.24</td>
#       <td id="T_9ba86_row0_col2" class="data row0 col2" >0.50</td>
#       <td id="T_9ba86_row0_col3" class="data row0 col3" >2000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row1_col0" class="data row1 col0" >-5</td>
#       <td id="T_9ba86_row1_col1" class="data row1 col1" >3.14</td>
#       <td id="T_9ba86_row1_col2" class="data row1 col2" >1.20</td>
#       <td id="T_9ba86_row1_col3" class="data row1 col3" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_9ba86_row2_col1" class="data row2 col1" >2.71</td>
#       <td id="T_9ba86_row2_col2" class="data row2 col2" >0.30</td>
#       <td id="T_9ba86_row2_col3" class="data row2 col3" >1000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row3_col0" class="data row3 col0" >-4</td>
#       <td id="T_9ba86_row3_col1" class="data row3 col1" >-3.14</td>
#       <td id="T_9ba86_row3_col2" class="data row3 col2" >1.90</td>
#       <td id="T_9ba86_row3_col3" class="data row3 col3" >7000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_9ba86_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_9ba86_row4_col2" class="data row4 col2" >2.20</td>
#       <td id="T_9ba86_row4_col3" class="data row4 col3" >5000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.format("- {:.3f} -")
# Out:
# <style type="text/css">
# </style>
# <table id="T_9ba86">
#   <thead>
#     <tr>
#       <th id="T_9ba86_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9ba86_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_9ba86_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_9ba86_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ba86_row0_col0" class="data row0 col0" >- 0.000 -</td>
#       <td id="T_9ba86_row0_col1" class="data row0 col1" >- 12.240 -</td>
#       <td id="T_9ba86_row0_col2" class="data row0 col2" >- 0.500 -</td>
#       <td id="T_9ba86_row0_col3" class="data row0 col3" >- 2000.000 -</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row1_col0" class="data row1 col0" >- -5.000 -</td>
#       <td id="T_9ba86_row1_col1" class="data row1 col1" >- 3.140 -</td>
#       <td id="T_9ba86_row1_col2" class="data row1 col2" >- 1.200 -</td>
#       <td id="T_9ba86_row1_col3" class="data row1 col3" >- nan -</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row2_col0" class="data row2 col0" >- 12.000 -</td>
#       <td id="T_9ba86_row2_col1" class="data row2 col1" >- 2.710 -</td>
#       <td id="T_9ba86_row2_col2" class="data row2 col2" >- 0.300 -</td>
#       <td id="T_9ba86_row2_col3" class="data row2 col3" >- 1000.000 -</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row3_col0" class="data row3 col0" >- -4.000 -</td>
#       <td id="T_9ba86_row3_col1" class="data row3 col1" >- -3.140 -</td>
#       <td id="T_9ba86_row3_col2" class="data row3 col2" >- 1.900 -</td>
#       <td id="T_9ba86_row3_col3" class="data row3 col3" >- 7000.000 -</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row4_col0" class="data row4 col0" >- 3.000 -</td>
#       <td id="T_9ba86_row4_col1" class="data row4 col1" >- nan -</td>
#       <td id="T_9ba86_row4_col2" class="data row4 col2" >- 2.200 -</td>
#       <td id="T_9ba86_row4_col3" class="data row4 col3" >- 5000.000 -</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.format({
    "A": "{:.2f}",
    "B": "{:,.5f}",
    "C": "{:.1f}",
    "D": "$ {:,.2f}"
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_9ba86">
#   <thead>
#     <tr>
#       <th id="T_9ba86_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9ba86_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_9ba86_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_9ba86_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ba86_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_9ba86_row0_col1" class="data row0 col1" >12.24000</td>
#       <td id="T_9ba86_row0_col2" class="data row0 col2" >0.5</td>
#       <td id="T_9ba86_row0_col3" class="data row0 col3" >$ 2,000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row1_col0" class="data row1 col0" >-5.00</td>
#       <td id="T_9ba86_row1_col1" class="data row1 col1" >3.14000</td>
#       <td id="T_9ba86_row1_col2" class="data row1 col2" >1.2</td>
#       <td id="T_9ba86_row1_col3" class="data row1 col3" >$ nan</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row2_col0" class="data row2 col0" >12.00</td>
#       <td id="T_9ba86_row2_col1" class="data row2 col1" >2.71000</td>
#       <td id="T_9ba86_row2_col2" class="data row2 col2" >0.3</td>
#       <td id="T_9ba86_row2_col3" class="data row2 col3" >$ 1,000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row3_col0" class="data row3 col0" >-4.00</td>
#       <td id="T_9ba86_row3_col1" class="data row3 col1" >-3.14000</td>
#       <td id="T_9ba86_row3_col2" class="data row3 col2" >1.9</td>
#       <td id="T_9ba86_row3_col3" class="data row3 col3" >$ 7,000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row4_col0" class="data row4 col0" >3.00</td>
#       <td id="T_9ba86_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_9ba86_row4_col2" class="data row4 col2" >2.2</td>
#       <td id="T_9ba86_row4_col3" class="data row4 col3" >$ 5,000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.highlight_max()
# Out:
# <style type="text/css">
# #T_9ba86_row0_col1, #T_9ba86_row2_col0, #T_9ba86_row3_col3, #T_9ba86_row4_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_9ba86">
#   <thead>
#     <tr>
#       <th id="T_9ba86_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9ba86_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_9ba86_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_9ba86_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ba86_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_9ba86_row0_col1" class="data row0 col1" >12.24000</td>
#       <td id="T_9ba86_row0_col2" class="data row0 col2" >0.5</td>
#       <td id="T_9ba86_row0_col3" class="data row0 col3" >$ 2,000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row1_col0" class="data row1 col0" >-5.00</td>
#       <td id="T_9ba86_row1_col1" class="data row1 col1" >3.14000</td>
#       <td id="T_9ba86_row1_col2" class="data row1 col2" >1.2</td>
#       <td id="T_9ba86_row1_col3" class="data row1 col3" >$ nan</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row2_col0" class="data row2 col0" >12.00</td>
#       <td id="T_9ba86_row2_col1" class="data row2 col1" >2.71000</td>
#       <td id="T_9ba86_row2_col2" class="data row2 col2" >0.3</td>
#       <td id="T_9ba86_row2_col3" class="data row2 col3" >$ 1,000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row3_col0" class="data row3 col0" >-4.00</td>
#       <td id="T_9ba86_row3_col1" class="data row3 col1" >-3.14000</td>
#       <td id="T_9ba86_row3_col2" class="data row3 col2" >1.9</td>
#       <td id="T_9ba86_row3_col3" class="data row3 col3" >$ 7,000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row4_col0" class="data row4 col0" >3.00</td>
#       <td id="T_9ba86_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_9ba86_row4_col2" class="data row4 col2" >2.2</td>
#       <td id="T_9ba86_row4_col3" class="data row4 col3" >$ 5,000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.highlight_min()
# Out:
# <style type="text/css">
# #T_9ba86_row0_col1, #T_9ba86_row1_col0, #T_9ba86_row2_col0, #T_9ba86_row2_col2, #T_9ba86_row2_col3, #T_9ba86_row3_col1, #T_9ba86_row3_col3, #T_9ba86_row4_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_9ba86">
#   <thead>
#     <tr>
#       <th id="T_9ba86_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9ba86_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_9ba86_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_9ba86_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ba86_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_9ba86_row0_col1" class="data row0 col1" >12.24000</td>
#       <td id="T_9ba86_row0_col2" class="data row0 col2" >0.5</td>
#       <td id="T_9ba86_row0_col3" class="data row0 col3" >$ 2,000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row1_col0" class="data row1 col0" >-5.00</td>
#       <td id="T_9ba86_row1_col1" class="data row1 col1" >3.14000</td>
#       <td id="T_9ba86_row1_col2" class="data row1 col2" >1.2</td>
#       <td id="T_9ba86_row1_col3" class="data row1 col3" >$ nan</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row2_col0" class="data row2 col0" >12.00</td>
#       <td id="T_9ba86_row2_col1" class="data row2 col1" >2.71000</td>
#       <td id="T_9ba86_row2_col2" class="data row2 col2" >0.3</td>
#       <td id="T_9ba86_row2_col3" class="data row2 col3" >$ 1,000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row3_col0" class="data row3 col0" >-4.00</td>
#       <td id="T_9ba86_row3_col1" class="data row3 col1" >-3.14000</td>
#       <td id="T_9ba86_row3_col2" class="data row3 col2" >1.9</td>
#       <td id="T_9ba86_row3_col3" class="data row3 col3" >$ 7,000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row4_col0" class="data row4 col0" >3.00</td>
#       <td id="T_9ba86_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_9ba86_row4_col2" class="data row4 col2" >2.2</td>
#       <td id="T_9ba86_row4_col3" class="data row4 col3" >$ 5,000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.highlight_null(color="red")
# Out:
# <style type="text/css">
# #T_9ba86_row0_col1, #T_9ba86_row1_col0, #T_9ba86_row2_col0, #T_9ba86_row2_col2, #T_9ba86_row2_col3, #T_9ba86_row3_col1, #T_9ba86_row3_col3, #T_9ba86_row4_col2 {
#   background-color: yellow;
# }
# #T_9ba86_row1_col3, #T_9ba86_row4_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_9ba86">
#   <thead>
#     <tr>
#       <th id="T_9ba86_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9ba86_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_9ba86_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_9ba86_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ba86_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_9ba86_row0_col1" class="data row0 col1" >12.24000</td>
#       <td id="T_9ba86_row0_col2" class="data row0 col2" >0.5</td>
#       <td id="T_9ba86_row0_col3" class="data row0 col3" >$ 2,000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row1_col0" class="data row1 col0" >-5.00</td>
#       <td id="T_9ba86_row1_col1" class="data row1 col1" >3.14000</td>
#       <td id="T_9ba86_row1_col2" class="data row1 col2" >1.2</td>
#       <td id="T_9ba86_row1_col3" class="data row1 col3" >$ nan</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row2_col0" class="data row2 col0" >12.00</td>
#       <td id="T_9ba86_row2_col1" class="data row2 col1" >2.71000</td>
#       <td id="T_9ba86_row2_col2" class="data row2 col2" >0.3</td>
#       <td id="T_9ba86_row2_col3" class="data row2 col3" >$ 1,000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row3_col0" class="data row3 col0" >-4.00</td>
#       <td id="T_9ba86_row3_col1" class="data row3 col1" >-3.14000</td>
#       <td id="T_9ba86_row3_col2" class="data row3 col2" >1.9</td>
#       <td id="T_9ba86_row3_col3" class="data row3 col3" >$ 7,000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row4_col0" class="data row4 col0" >3.00</td>
#       <td id="T_9ba86_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_9ba86_row4_col2" class="data row4 col2" >2.2</td>
#       <td id="T_9ba86_row4_col3" class="data row4 col3" >$ 5,000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.format(na_rep="Missing").highlight_null(color="red")
# Out:
# <style type="text/css">
# #T_9ba86_row0_col1, #T_9ba86_row1_col0, #T_9ba86_row2_col0, #T_9ba86_row2_col2, #T_9ba86_row2_col3, #T_9ba86_row3_col1, #T_9ba86_row3_col3, #T_9ba86_row4_col2 {
#   background-color: yellow;
# }
# #T_9ba86_row1_col3, #T_9ba86_row4_col1 {
#   background-color: red;
#   background-color: red;
# }
# </style>
# <table id="T_9ba86">
#   <thead>
#     <tr>
#       <th id="T_9ba86_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9ba86_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_9ba86_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_9ba86_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ba86_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9ba86_row0_col1" class="data row0 col1" >12.240000</td>
#       <td id="T_9ba86_row0_col2" class="data row0 col2" >0.500000</td>
#       <td id="T_9ba86_row0_col3" class="data row0 col3" >2000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row1_col0" class="data row1 col0" >-5</td>
#       <td id="T_9ba86_row1_col1" class="data row1 col1" >3.140000</td>
#       <td id="T_9ba86_row1_col2" class="data row1 col2" >1.200000</td>
#       <td id="T_9ba86_row1_col3" class="data row1 col3" >Missing</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_9ba86_row2_col1" class="data row2 col1" >2.710000</td>
#       <td id="T_9ba86_row2_col2" class="data row2 col2" >0.300000</td>
#       <td id="T_9ba86_row2_col3" class="data row2 col3" >1000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row3_col0" class="data row3 col0" >-4</td>
#       <td id="T_9ba86_row3_col1" class="data row3 col1" >-3.140000</td>
#       <td id="T_9ba86_row3_col2" class="data row3 col2" >1.900000</td>
#       <td id="T_9ba86_row3_col3" class="data row3 col3" >7000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_9ba86_row4_col1" class="data row4 col1" >Missing</td>
#       <td id="T_9ba86_row4_col2" class="data row4 col2" >2.200000</td>
#       <td id="T_9ba86_row4_col3" class="data row4 col3" >5000.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.background_gradient()
# Out:
# <style type="text/css">
# #T_9ba86_row0_col0 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_9ba86_row0_col1, #T_9ba86_row2_col0, #T_9ba86_row3_col3, #T_9ba86_row4_col2 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9ba86_row0_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_9ba86_row0_col3 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_9ba86_row1_col0, #T_9ba86_row2_col2, #T_9ba86_row2_col3, #T_9ba86_row3_col1 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9ba86_row1_col1 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_9ba86_row1_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_9ba86_row1_col3, #T_9ba86_row4_col1 {
#   background-color: red;
#   background-color: red;
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_9ba86_row2_col1 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_9ba86_row3_col0 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_9ba86_row3_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_9ba86_row4_col0 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_9ba86_row4_col3 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9ba86">
#   <thead>
#     <tr>
#       <th id="T_9ba86_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9ba86_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_9ba86_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_9ba86_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ba86_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9ba86_row0_col1" class="data row0 col1" >12.240000</td>
#       <td id="T_9ba86_row0_col2" class="data row0 col2" >0.500000</td>
#       <td id="T_9ba86_row0_col3" class="data row0 col3" >2000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row1_col0" class="data row1 col0" >-5</td>
#       <td id="T_9ba86_row1_col1" class="data row1 col1" >3.140000</td>
#       <td id="T_9ba86_row1_col2" class="data row1 col2" >1.200000</td>
#       <td id="T_9ba86_row1_col3" class="data row1 col3" >Missing</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_9ba86_row2_col1" class="data row2 col1" >2.710000</td>
#       <td id="T_9ba86_row2_col2" class="data row2 col2" >0.300000</td>
#       <td id="T_9ba86_row2_col3" class="data row2 col3" >1000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row3_col0" class="data row3 col0" >-4</td>
#       <td id="T_9ba86_row3_col1" class="data row3 col1" >-3.140000</td>
#       <td id="T_9ba86_row3_col2" class="data row3 col2" >1.900000</td>
#       <td id="T_9ba86_row3_col3" class="data row3 col3" >7000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_9ba86_row4_col1" class="data row4 col1" >Missing</td>
#       <td id="T_9ba86_row4_col2" class="data row4 col2" >2.200000</td>
#       <td id="T_9ba86_row4_col3" class="data row4 col3" >5000.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.background_gradient(subset=["B", "D"])
# Out:
# <style type="text/css">
# #T_9ba86_row0_col0 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_9ba86_row0_col1, #T_9ba86_row3_col3 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9ba86_row0_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_9ba86_row0_col3 {
#   background-color: #e3e0ee;
#   color: #000000;
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_9ba86_row1_col0, #T_9ba86_row2_col2 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9ba86_row1_col1 {
#   background-color: #99b8d8;
#   color: #000000;
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_9ba86_row1_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_9ba86_row1_col3, #T_9ba86_row4_col1 {
#   background-color: red;
#   background-color: red;
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_9ba86_row2_col0, #T_9ba86_row4_col2 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9ba86_row2_col1 {
#   background-color: #a4bcda;
#   color: #000000;
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_9ba86_row2_col3, #T_9ba86_row3_col1 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9ba86_row3_col0 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_9ba86_row3_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_9ba86_row4_col0 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_9ba86_row4_col3 {
#   background-color: #2685bb;
#   color: #f1f1f1;
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9ba86">
#   <thead>
#     <tr>
#       <th id="T_9ba86_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9ba86_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_9ba86_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_9ba86_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ba86_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9ba86_row0_col1" class="data row0 col1" >12.240000</td>
#       <td id="T_9ba86_row0_col2" class="data row0 col2" >0.500000</td>
#       <td id="T_9ba86_row0_col3" class="data row0 col3" >2000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row1_col0" class="data row1 col0" >-5</td>
#       <td id="T_9ba86_row1_col1" class="data row1 col1" >3.140000</td>
#       <td id="T_9ba86_row1_col2" class="data row1 col2" >1.200000</td>
#       <td id="T_9ba86_row1_col3" class="data row1 col3" >Missing</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_9ba86_row2_col1" class="data row2 col1" >2.710000</td>
#       <td id="T_9ba86_row2_col2" class="data row2 col2" >0.300000</td>
#       <td id="T_9ba86_row2_col3" class="data row2 col3" >1000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row3_col0" class="data row3 col0" >-4</td>
#       <td id="T_9ba86_row3_col1" class="data row3 col1" >-3.140000</td>
#       <td id="T_9ba86_row3_col2" class="data row3 col2" >1.900000</td>
#       <td id="T_9ba86_row3_col3" class="data row3 col3" >7000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_9ba86_row4_col1" class="data row4 col1" >Missing</td>
#       <td id="T_9ba86_row4_col2" class="data row4 col2" >2.200000</td>
#       <td id="T_9ba86_row4_col3" class="data row4 col3" >5000.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.text_gradient(subset=["C"], cmap="RdYlGn", vmin=0, vmax=2.5)
# Out:
# <style type="text/css">
# #T_9ba86_row0_col0 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_9ba86_row0_col1, #T_9ba86_row3_col3 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9ba86_row0_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
#   color: #f46d43;
# }
# #T_9ba86_row0_col3 {
#   background-color: #e3e0ee;
#   color: #000000;
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_9ba86_row1_col0 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9ba86_row1_col1 {
#   background-color: #99b8d8;
#   color: #000000;
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_9ba86_row1_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
#   color: #fff8b4;
# }
# #T_9ba86_row1_col3, #T_9ba86_row4_col1 {
#   background-color: red;
#   background-color: red;
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_9ba86_row2_col0 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9ba86_row2_col1 {
#   background-color: #a4bcda;
#   color: #000000;
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_9ba86_row2_col2 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   color: #dc3b2c;
# }
# #T_9ba86_row2_col3, #T_9ba86_row3_col1 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9ba86_row3_col0 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_9ba86_row3_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
#   color: #7fc866;
# }
# #T_9ba86_row4_col0 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_9ba86_row4_col2 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   color: #279f53;
# }
# #T_9ba86_row4_col3 {
#   background-color: #2685bb;
#   color: #f1f1f1;
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9ba86">
#   <thead>
#     <tr>
#       <th id="T_9ba86_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9ba86_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_9ba86_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_9ba86_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ba86_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9ba86_row0_col1" class="data row0 col1" >12.240000</td>
#       <td id="T_9ba86_row0_col2" class="data row0 col2" >0.500000</td>
#       <td id="T_9ba86_row0_col3" class="data row0 col3" >2000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row1_col0" class="data row1 col0" >-5</td>
#       <td id="T_9ba86_row1_col1" class="data row1 col1" >3.140000</td>
#       <td id="T_9ba86_row1_col2" class="data row1 col2" >1.200000</td>
#       <td id="T_9ba86_row1_col3" class="data row1 col3" >Missing</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_9ba86_row2_col1" class="data row2 col1" >2.710000</td>
#       <td id="T_9ba86_row2_col2" class="data row2 col2" >0.300000</td>
#       <td id="T_9ba86_row2_col3" class="data row2 col3" >1000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row3_col0" class="data row3 col0" >-4</td>
#       <td id="T_9ba86_row3_col1" class="data row3 col1" >-3.140000</td>
#       <td id="T_9ba86_row3_col2" class="data row3 col2" >1.900000</td>
#       <td id="T_9ba86_row3_col3" class="data row3 col3" >7000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_9ba86_row4_col1" class="data row4 col1" >Missing</td>
#       <td id="T_9ba86_row4_col2" class="data row4 col2" >2.200000</td>
#       <td id="T_9ba86_row4_col3" class="data row4 col3" >5000.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.background_gradient(subset=["C"], cmap="RdYlGn", vmin=0, vmax=2.5)
# Out:
# <style type="text/css">
# #T_9ba86_row0_col0 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_9ba86_row0_col1, #T_9ba86_row3_col3 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9ba86_row0_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
#   color: #f46d43;
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_9ba86_row0_col3 {
#   background-color: #e3e0ee;
#   color: #000000;
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_9ba86_row1_col0 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9ba86_row1_col1 {
#   background-color: #99b8d8;
#   color: #000000;
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_9ba86_row1_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
#   color: #fff8b4;
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_9ba86_row1_col3, #T_9ba86_row4_col1 {
#   background-color: red;
#   background-color: red;
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_9ba86_row2_col0 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9ba86_row2_col1 {
#   background-color: #a4bcda;
#   color: #000000;
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_9ba86_row2_col2 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   color: #dc3b2c;
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_9ba86_row2_col3, #T_9ba86_row3_col1 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9ba86_row3_col0 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_9ba86_row3_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
#   color: #7fc866;
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_9ba86_row4_col0 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_9ba86_row4_col2 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   color: #279f53;
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_9ba86_row4_col3 {
#   background-color: #2685bb;
#   color: #f1f1f1;
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9ba86">
#   <thead>
#     <tr>
#       <th id="T_9ba86_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9ba86_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_9ba86_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_9ba86_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ba86_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9ba86_row0_col1" class="data row0 col1" >12.240000</td>
#       <td id="T_9ba86_row0_col2" class="data row0 col2" >0.500000</td>
#       <td id="T_9ba86_row0_col3" class="data row0 col3" >2000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row1_col0" class="data row1 col0" >-5</td>
#       <td id="T_9ba86_row1_col1" class="data row1 col1" >3.140000</td>
#       <td id="T_9ba86_row1_col2" class="data row1 col2" >1.200000</td>
#       <td id="T_9ba86_row1_col3" class="data row1 col3" >Missing</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_9ba86_row2_col1" class="data row2 col1" >2.710000</td>
#       <td id="T_9ba86_row2_col2" class="data row2 col2" >0.300000</td>
#       <td id="T_9ba86_row2_col3" class="data row2 col3" >1000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row3_col0" class="data row3 col0" >-4</td>
#       <td id="T_9ba86_row3_col1" class="data row3 col1" >-3.140000</td>
#       <td id="T_9ba86_row3_col2" class="data row3 col2" >1.900000</td>
#       <td id="T_9ba86_row3_col3" class="data row3 col3" >7000.000000</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_9ba86_row4_col1" class="data row4 col1" >Missing</td>
#       <td id="T_9ba86_row4_col2" class="data row4 col2" >2.200000</td>
#       <td id="T_9ba86_row4_col3" class="data row4 col3" >5000.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.format(precision=2).bar(color="orange")
# Out:
# <style type="text/css">
# #T_9ba86_row0_col0 {
#   background-color: #c1cae2;
#   color: #000000;
#   width: 10em;
# }
# #T_9ba86_row0_col1 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 100.0%, transparent 100.0%);
# }
# #T_9ba86_row0_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
#   color: #f46d43;
#   background-color: #f46d43;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 22.7%, transparent 22.7%);
# }
# #T_9ba86_row0_col3 {
#   background-color: #e3e0ee;
#   color: #000000;
#   background-color: #e3e0ee;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 28.6%, transparent 28.6%);
# }
# #T_9ba86_row1_col0 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 29.4%, transparent 29.4%);
# }
# #T_9ba86_row1_col1 {
#   background-color: #99b8d8;
#   color: #000000;
#   background-color: #99b8d8;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 40.8%, transparent 40.8%);
# }
# #T_9ba86_row1_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
#   color: #fff8b4;
#   background-color: #fff8b4;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 54.5%, transparent 54.5%);
# }
# #T_9ba86_row1_col3, #T_9ba86_row4_col1 {
#   background-color: red;
#   background-color: red;
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #000000;
#   color: #f1f1f1;
#   width: 10em;
# }
# #T_9ba86_row2_col0 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, orange 29.4%, orange 100.0%, transparent 100.0%);
# }
# #T_9ba86_row2_col1 {
#   background-color: #a4bcda;
#   color: #000000;
#   background-color: #a4bcda;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 38.0%, transparent 38.0%);
# }
# #T_9ba86_row2_col2 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   color: #dc3b2c;
#   background-color: #dc3b2c;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 13.6%, transparent 13.6%);
# }
# #T_9ba86_row2_col3 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 14.3%, transparent 14.3%);
# }
# #T_9ba86_row3_col0 {
#   background-color: #f6eff7;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 5.9%, orange 5.9%, orange 29.4%, transparent 29.4%);
# }
# #T_9ba86_row3_col1 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 20.4%, transparent 20.4%);
# }
# #T_9ba86_row3_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
#   color: #7fc866;
#   background-color: #7fc866;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 86.4%, transparent 86.4%);
# }
# #T_9ba86_row3_col3 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 100.0%, transparent 100.0%);
# }
# #T_9ba86_row4_col0 {
#   background-color: #80aed2;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, orange 29.4%, orange 47.1%, transparent 47.1%);
# }
# #T_9ba86_row4_col2 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   color: #279f53;
#   background-color: #279f53;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 100.0%, transparent 100.0%);
# }
# #T_9ba86_row4_col3 {
#   background-color: #2685bb;
#   color: #f1f1f1;
#   background-color: #2685bb;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 71.4%, transparent 71.4%);
# }
# </style>
# <table id="T_9ba86">
#   <thead>
#     <tr>
#       <th id="T_9ba86_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9ba86_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_9ba86_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_9ba86_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ba86_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9ba86_row0_col1" class="data row0 col1" >12.24</td>
#       <td id="T_9ba86_row0_col2" class="data row0 col2" >0.50</td>
#       <td id="T_9ba86_row0_col3" class="data row0 col3" >2000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row1_col0" class="data row1 col0" >-5</td>
#       <td id="T_9ba86_row1_col1" class="data row1 col1" >3.14</td>
#       <td id="T_9ba86_row1_col2" class="data row1 col2" >1.20</td>
#       <td id="T_9ba86_row1_col3" class="data row1 col3" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_9ba86_row2_col1" class="data row2 col1" >2.71</td>
#       <td id="T_9ba86_row2_col2" class="data row2 col2" >0.30</td>
#       <td id="T_9ba86_row2_col3" class="data row2 col3" >1000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row3_col0" class="data row3 col0" >-4</td>
#       <td id="T_9ba86_row3_col1" class="data row3 col1" >-3.14</td>
#       <td id="T_9ba86_row3_col2" class="data row3 col2" >1.90</td>
#       <td id="T_9ba86_row3_col3" class="data row3 col3" >7000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_9ba86_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_9ba86_row4_col2" class="data row4 col2" >2.20</td>
#       <td id="T_9ba86_row4_col3" class="data row4 col3" >5000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.format(precision=2).bar(align="mid", color=["red", "lightgreen"]).set_properties(**{"border": "1px solid black"})
# Out:
# <style type="text/css">
# #T_9ba86_row0_col0 {
#   background-color: #c1cae2;
#   color: #000000;
#   width: 10em;
#   width: 10em;
#   border: 1px solid black;
# }
# #T_9ba86_row0_col1 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, lightgreen 20.4%, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
# }
# #T_9ba86_row0_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
#   color: #f46d43;
#   background-color: #f46d43;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 22.7%, transparent 22.7%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 22.7%, transparent 22.7%);
#   border: 1px solid black;
# }
# #T_9ba86_row0_col3 {
#   background-color: #e3e0ee;
#   color: #000000;
#   background-color: #e3e0ee;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 28.6%, transparent 28.6%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 28.6%, transparent 28.6%);
#   border: 1px solid black;
# }
# #T_9ba86_row1_col0 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 29.4%, transparent 29.4%);
#   width: 10em;
#   background: linear-gradient(90deg, red 29.4%, transparent 29.4%);
#   border: 1px solid black;
# }
# #T_9ba86_row1_col1 {
#   background-color: #99b8d8;
#   color: #000000;
#   background-color: #99b8d8;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 40.8%, transparent 40.8%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, lightgreen 20.4%, lightgreen 40.8%, transparent 40.8%);
#   border: 1px solid black;
# }
# #T_9ba86_row1_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
#   color: #fff8b4;
#   background-color: #fff8b4;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 54.5%, transparent 54.5%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 54.5%, transparent 54.5%);
#   border: 1px solid black;
# }
# #T_9ba86_row1_col3, #T_9ba86_row4_col1 {
#   background-color: red;
#   background-color: red;
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #000000;
#   color: #f1f1f1;
#   width: 10em;
#   width: 10em;
#   border: 1px solid black;
# }
# #T_9ba86_row2_col0 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, orange 29.4%, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, lightgreen 29.4%, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
# }
# #T_9ba86_row2_col1 {
#   background-color: #a4bcda;
#   color: #000000;
#   background-color: #a4bcda;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 38.0%, transparent 38.0%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, lightgreen 20.4%, lightgreen 38.0%, transparent 38.0%);
#   border: 1px solid black;
# }
# #T_9ba86_row2_col2 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   color: #dc3b2c;
#   background-color: #dc3b2c;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 13.6%, transparent 13.6%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 13.6%, transparent 13.6%);
#   border: 1px solid black;
# }
# #T_9ba86_row2_col3 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 14.3%, transparent 14.3%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 14.3%, transparent 14.3%);
#   border: 1px solid black;
# }
# #T_9ba86_row3_col0 {
#   background-color: #f6eff7;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 5.9%, orange 5.9%, orange 29.4%, transparent 29.4%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 5.9%, red 5.9%, red 29.4%, transparent 29.4%);
#   border: 1px solid black;
# }
# #T_9ba86_row3_col1 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 20.4%, transparent 20.4%);
#   width: 10em;
#   background: linear-gradient(90deg, red 20.4%, transparent 20.4%);
#   border: 1px solid black;
# }
# #T_9ba86_row3_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
#   color: #7fc866;
#   background-color: #7fc866;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 86.4%, transparent 86.4%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 86.4%, transparent 86.4%);
#   border: 1px solid black;
# }
# #T_9ba86_row3_col3 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
# }
# #T_9ba86_row4_col0 {
#   background-color: #80aed2;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, orange 29.4%, orange 47.1%, transparent 47.1%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, lightgreen 29.4%, lightgreen 47.1%, transparent 47.1%);
#   border: 1px solid black;
# }
# #T_9ba86_row4_col2 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   color: #279f53;
#   background-color: #279f53;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
# }
# #T_9ba86_row4_col3 {
#   background-color: #2685bb;
#   color: #f1f1f1;
#   background-color: #2685bb;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 71.4%, transparent 71.4%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 71.4%, transparent 71.4%);
#   border: 1px solid black;
# }
# </style>
# <table id="T_9ba86">
#   <thead>
#     <tr>
#       <th id="T_9ba86_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9ba86_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_9ba86_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_9ba86_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ba86_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9ba86_row0_col1" class="data row0 col1" >12.24</td>
#       <td id="T_9ba86_row0_col2" class="data row0 col2" >0.50</td>
#       <td id="T_9ba86_row0_col3" class="data row0 col3" >2000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row1_col0" class="data row1 col0" >-5</td>
#       <td id="T_9ba86_row1_col1" class="data row1 col1" >3.14</td>
#       <td id="T_9ba86_row1_col2" class="data row1 col2" >1.20</td>
#       <td id="T_9ba86_row1_col3" class="data row1 col3" >nan</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_9ba86_row2_col1" class="data row2 col1" >2.71</td>
#       <td id="T_9ba86_row2_col2" class="data row2 col2" >0.30</td>
#       <td id="T_9ba86_row2_col3" class="data row2 col3" >1000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row3_col0" class="data row3 col0" >-4</td>
#       <td id="T_9ba86_row3_col1" class="data row3 col1" >-3.14</td>
#       <td id="T_9ba86_row3_col2" class="data row3 col2" >1.90</td>
#       <td id="T_9ba86_row3_col3" class="data row3 col3" >7000.00</td>
#     </tr>
#     <tr>
#       <td id="T_9ba86_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_9ba86_row4_col1"

# %%
properties = {"border": "2px solid gray", "color": "green", "font-size": "16px"}
df.set_properties(**properties)
# Out:
# <style type="text/css">
# #T_9ba86_row0_col0 {
#   background-color: #c1cae2;
#   color: #000000;
#   width: 10em;
#   width: 10em;
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row0_col1 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, lightgreen 20.4%, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row0_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
#   color: #f46d43;
#   background-color: #f46d43;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 22.7%, transparent 22.7%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 22.7%, transparent 22.7%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row0_col3 {
#   background-color: #e3e0ee;
#   color: #000000;
#   background-color: #e3e0ee;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 28.6%, transparent 28.6%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 28.6%, transparent 28.6%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row1_col0 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 29.4%, transparent 29.4%);
#   width: 10em;
#   background: linear-gradient(90deg, red 29.4%, transparent 29.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row1_col1 {
#   background-color: #99b8d8;
#   color: #000000;
#   background-color: #99b8d8;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 40.8%, transparent 40.8%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, lightgreen 20.4%, lightgreen 40.8%, transparent 40.8%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row1_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
#   color: #fff8b4;
#   background-color: #fff8b4;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 54.5%, transparent 54.5%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 54.5%, transparent 54.5%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row1_col3, #T_9ba86_row4_col1 {
#   background-color: red;
#   background-color: red;
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #000000;
#   color: #f1f1f1;
#   width: 10em;
#   width: 10em;
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row2_col0 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, orange 29.4%, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, lightgreen 29.4%, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row2_col1 {
#   background-color: #a4bcda;
#   color: #000000;
#   background-color: #a4bcda;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 38.0%, transparent 38.0%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, lightgreen 20.4%, lightgreen 38.0%, transparent 38.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row2_col2 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   color: #dc3b2c;
#   background-color: #dc3b2c;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 13.6%, transparent 13.6%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 13.6%, transparent 13.6%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row2_col3 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 14.3%, transparent 14.3%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 14.3%, transparent 14.3%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row3_col0 {
#   background-color: #f6eff7;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 5.9%, orange 5.9%, orange 29.4%, transparent 29.4%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 5.9%, red 5.9%, red 29.4%, transparent 29.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row3_col1 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 20.4%, transparent 20.4%);
#   width: 10em;
#   background: linear-gradient(90deg, red 20.4%, transparent 20.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row3_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
#   color: #7fc866;
#   background-color: #7fc866;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 86.4%, transparent 86.4%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 86.4%, transparent 86.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row3_col3 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row4_col0 {
#   background-color: #80aed2;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, orange 29.4%, orange 47.1%, transparent 47.1%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, lightgreen 29.4%, lightgreen 47.1%, transparent 47.1%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row4_col2 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   color: #279f53;
#   background-color: #279f53;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row4_col3 {
#   background-color: #2685bb;
#   color: #f1f1f1;
#   background-color: #2685bb;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 71.4%, transparent 71.4%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 71.4%, transparent 71.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# </style>
# <table id="T_9ba86">
#   <thead>
#     <tr>
#       <th id="T_9ba86_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9ba86_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_9ba86_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_9ba86_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ba86_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9ba86_r

# %%
cell_hover = {
    "selector": "td:hover",
    "props": [("background-color", "#FFFFE0")]
}
index_names = {
    "selector": ".index_name",
    "props": "font-style: italic; color: darkgrey; font-weight:normal;"
}
headers = {
    "selector": "th:not(.index_name)",
    "props": "background-color: #800000; color: white;"
}

df.set_table_styles([cell_hover, index_names, headers])
# Out:
# <style type="text/css">
# #T_9ba86 td:hover {
#   background-color: #FFFFE0;
# }
# #T_9ba86 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_9ba86 th:not(.index_name) {
#   background-color: #800000;
#   color: white;
# }
# #T_9ba86_row0_col0 {
#   background-color: #c1cae2;
#   color: #000000;
#   width: 10em;
#   width: 10em;
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row0_col1 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, lightgreen 20.4%, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row0_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
#   color: #f46d43;
#   background-color: #f46d43;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 22.7%, transparent 22.7%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 22.7%, transparent 22.7%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row0_col3 {
#   background-color: #e3e0ee;
#   color: #000000;
#   background-color: #e3e0ee;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 28.6%, transparent 28.6%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 28.6%, transparent 28.6%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row1_col0 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 29.4%, transparent 29.4%);
#   width: 10em;
#   background: linear-gradient(90deg, red 29.4%, transparent 29.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row1_col1 {
#   background-color: #99b8d8;
#   color: #000000;
#   background-color: #99b8d8;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 40.8%, transparent 40.8%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, lightgreen 20.4%, lightgreen 40.8%, transparent 40.8%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row1_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
#   color: #fff8b4;
#   background-color: #fff8b4;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 54.5%, transparent 54.5%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 54.5%, transparent 54.5%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row1_col3, #T_9ba86_row4_col1 {
#   background-color: red;
#   background-color: red;
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #000000;
#   color: #f1f1f1;
#   width: 10em;
#   width: 10em;
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row2_col0 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, orange 29.4%, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, lightgreen 29.4%, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row2_col1 {
#   background-color: #a4bcda;
#   color: #000000;
#   background-color: #a4bcda;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 38.0%, transparent 38.0%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, lightgreen 20.4%, lightgreen 38.0%, transparent 38.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row2_col2 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   color: #dc3b2c;
#   background-color: #dc3b2c;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 13.6%, transparent 13.6%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 13.6%, transparent 13.6%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row2_col3 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 14.3%, transparent 14.3%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 14.3%, transparent 14.3%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row3_col0 {
#   background-color: #f6eff7;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 5.9%, orange 5.9%, orange 29.4%, transparent 29.4%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 5.9%, red 5.9%, red 29.4%, transparent 29.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row3_col1 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 20.4%, transparent 20.4%);
#   width: 10em;
#   background: linear-gradient(90deg, red 20.4%, transparent 20.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row3_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
#   color: #7fc866;
#   background-color: #7fc866;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 86.4%, transparent 86.4%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 86.4%, transparent 86.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row3_col3 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row4_col0 {
#   background-color: #80aed2;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, orange 29.4%, orange 47.1%, transparent 47.1%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, lightgreen 29.4%, lightgreen 47.1%, transparent 47.1%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row4_col2 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   color: #279f53;
#   background-color: #279f53;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# #T_9ba86_row4_col3 {
#   background-color: #2685bb;
#   color: #f1f1f1;
#   background-color: #2685bb;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 71.4%, transparent 71.4%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 71.4%, transparent 71.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
# }
# </style>
# <table id="T_9ba86">
#   <thead>
#     <tr>
#       <th id="T_9ba86_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9ba86_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_9ba86_level0_col2" class="col_heading level

# %%
headers = {
    "selector": "th:not(.index_name)",
    "props": "background-color: #800000; color: white; text-align: center"
}
properties = {"border": "1px solid black", "width": "65px", "text-align": "center"}

df.format(precision=2).set_table_styles([cell_hover, index_names, headers]).set_properties(**properties)
# Out:
# <style type="text/css">
# #T_9ba86 td:hover {
#   background-color: #FFFFE0;
# }
# #T_9ba86 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_9ba86 th:not(.index_name) {
#   background-color: #800000;
#   color: white;
#   text-align: center;
# }
# #T_9ba86_row0_col0 {
#   background-color: #c1cae2;
#   color: #000000;
#   width: 10em;
#   width: 10em;
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_9ba86_row0_col1 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, lightgreen 20.4%, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_9ba86_row0_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
#   color: #f46d43;
#   background-color: #f46d43;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 22.7%, transparent 22.7%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 22.7%, transparent 22.7%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_9ba86_row0_col3 {
#   background-color: #e3e0ee;
#   color: #000000;
#   background-color: #e3e0ee;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 28.6%, transparent 28.6%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 28.6%, transparent 28.6%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_9ba86_row1_col0 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 29.4%, transparent 29.4%);
#   width: 10em;
#   background: linear-gradient(90deg, red 29.4%, transparent 29.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_9ba86_row1_col1 {
#   background-color: #99b8d8;
#   color: #000000;
#   background-color: #99b8d8;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 40.8%, transparent 40.8%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, lightgreen 20.4%, lightgreen 40.8%, transparent 40.8%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_9ba86_row1_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
#   color: #fff8b4;
#   background-color: #fff8b4;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 54.5%, transparent 54.5%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 54.5%, transparent 54.5%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_9ba86_row1_col3, #T_9ba86_row4_col1 {
#   background-color: red;
#   background-color: red;
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #000000;
#   color: #f1f1f1;
#   width: 10em;
#   width: 10em;
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_9ba86_row2_col0 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, orange 29.4%, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, lightgreen 29.4%, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_9ba86_row2_col1 {
#   background-color: #a4bcda;
#   color: #000000;
#   background-color: #a4bcda;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 38.0%, transparent 38.0%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, lightgreen 20.4%, lightgreen 38.0%, transparent 38.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_9ba86_row2_col2 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   color: #dc3b2c;
#   background-color: #dc3b2c;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 13.6%, transparent 13.6%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 13.6%, transparent 13.6%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_9ba86_row2_col3 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 14.3%, transparent 14.3%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 14.3%, transparent 14.3%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_9ba86_row3_col0 {
#   background-color: #f6eff7;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 5.9%, orange 5.9%, orange 29.4%, transparent 29.4%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 5.9%, red 5.9%, red 29.4%, transparent 29.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_9ba86_row3_col1 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 20.4%, transparent 20.4%);
#   width: 10em;
#   background: linear-gradient(90deg, red 20.4%, transparent 20.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_9ba86_row3_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
#   color: #7fc866;
#   background-color: #7fc866;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 86.4%, transparent 86.4%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 86.4%, transparent 86.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_9ba86_row3_col3 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
# }
# #T_9ba86_row4_col0 {
#   background-color: #80aed2;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, orange 29.4%, orange 47.1%, transparent 47.1%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, lightgreen 29.4%, lightgreen 47.1%, transparent 47.1%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;

# %%
def mean_highlighter(x):
    style_lt = "background-color: #EE2E31; color: white; font-weight: bold;"
    style_gt = "background-color: #31D843; color: white; font-weight: bold;"
    gt_mean = x > x.mean()
    return [style_gt if i else style_lt for i in gt_mean]
    
    
df.apply(mean_highlighter)
# Out:
# <style type="text/css">
# #T_9ba86 td:hover {
#   background-color: #FFFFE0;
# }
# #T_9ba86 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_9ba86 th:not(.index_name) {
#   background-color: #800000;
#   color: white;
#   text-align: center;
# }
# #T_9ba86_row0_col0 {
#   background-color: #c1cae2;
#   color: #000000;
#   width: 10em;
#   width: 10em;
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
# }
# #T_9ba86_row0_col1 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, lightgreen 20.4%, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #31D843;
#   color: white;
#   font-weight: bold;
# }
# #T_9ba86_row0_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
#   color: #f46d43;
#   background-color: #f46d43;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 22.7%, transparent 22.7%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 22.7%, transparent 22.7%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
# }
# #T_9ba86_row0_col3 {
#   background-color: #e3e0ee;
#   color: #000000;
#   background-color: #e3e0ee;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 28.6%, transparent 28.6%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 28.6%, transparent 28.6%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
# }
# #T_9ba86_row1_col0 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 29.4%, transparent 29.4%);
#   width: 10em;
#   background: linear-gradient(90deg, red 29.4%, transparent 29.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
# }
# #T_9ba86_row1_col1 {
#   background-color: #99b8d8;
#   color: #000000;
#   background-color: #99b8d8;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 40.8%, transparent 40.8%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, lightgreen 20.4%, lightgreen 40.8%, transparent 40.8%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
# }
# #T_9ba86_row1_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
#   color: #fff8b4;
#   background-color: #fff8b4;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 54.5%, transparent 54.5%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 54.5%, transparent 54.5%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
# }
# #T_9ba86_row1_col3, #T_9ba86_row4_col1 {
#   background-color: red;
#   background-color: red;
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #000000;
#   color: #f1f1f1;
#   width: 10em;
#   width: 10em;
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
# }
# #T_9ba86_row2_col0 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, orange 29.4%, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, lightgreen 29.4%, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #31D843;
#   color: white;
#   font-weight: bold;
# }
# #T_9ba86_row2_col1 {
#   background-color: #a4bcda;
#   color: #000000;
#   background-color: #a4bcda;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 38.0%, transparent 38.0%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, lightgreen 20.4%, lightgreen 38.0%, transparent 38.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
# }
# #T_9ba86_row2_col2 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   color: #dc3b2c;
#   background-color: #dc3b2c;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 13.6%, transparent 13.6%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 13.6%, transparent 13.6%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
# }
# #T_9ba86_row2_col3 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 14.3%, transparent 14.3%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 14.3%, transparent 14.3%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
# }
# #T_9ba86_row3_col0 {
#   background-color: #f6eff7;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 5.9%, orange 5.9%, orange 29.4%, transparent 29.4%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 5.9%, red 5.9%, red 29.4%, transparent 29.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
# }
# #T_9ba86_row3_col1 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 20.4%, transparent 20.4%);
#   width: 10em;
#   background: linear-gradient(90deg, red 20.4%, transparent 20.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
# }
# #T_9ba86_row3_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
#   color: #7fc866;
#   background-color: #7fc866;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 86.4%, transparent 86.4%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 86.4%, transparent 86.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   tex

# %%
def negative_highlighter(x):
    is_negative = x < 0
    return ["color: #EE2E31" if i else "color: #000000" for i in is_negative]
    
    
df.apply(negative_highlighter)
# Out:
# <style type="text/css">
# #T_9ba86 td:hover {
#   background-color: #FFFFE0;
# }
# #T_9ba86 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_9ba86 th:not(.index_name) {
#   background-color: #800000;
#   color: white;
#   text-align: center;
# }
# #T_9ba86_row0_col0 {
#   background-color: #c1cae2;
#   color: #000000;
#   width: 10em;
#   width: 10em;
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
#   color: #000000;
# }
# #T_9ba86_row0_col1 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, lightgreen 20.4%, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #31D843;
#   color: white;
#   font-weight: bold;
#   color: #000000;
# }
# #T_9ba86_row0_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
#   color: #f46d43;
#   background-color: #f46d43;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 22.7%, transparent 22.7%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 22.7%, transparent 22.7%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
#   color: #000000;
# }
# #T_9ba86_row0_col3 {
#   background-color: #e3e0ee;
#   color: #000000;
#   background-color: #e3e0ee;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 28.6%, transparent 28.6%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 28.6%, transparent 28.6%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
#   color: #000000;
# }
# #T_9ba86_row1_col0 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 29.4%, transparent 29.4%);
#   width: 10em;
#   background: linear-gradient(90deg, red 29.4%, transparent 29.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
#   color: #EE2E31;
# }
# #T_9ba86_row1_col1 {
#   background-color: #99b8d8;
#   color: #000000;
#   background-color: #99b8d8;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 40.8%, transparent 40.8%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, lightgreen 20.4%, lightgreen 40.8%, transparent 40.8%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
#   color: #000000;
# }
# #T_9ba86_row1_col2 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
#   color: #fff8b4;
#   background-color: #fff8b4;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 54.5%, transparent 54.5%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 54.5%, transparent 54.5%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
#   color: #000000;
# }
# #T_9ba86_row1_col3, #T_9ba86_row4_col1 {
#   background-color: red;
#   background-color: red;
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #000000;
#   color: #f1f1f1;
#   width: 10em;
#   width: 10em;
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
#   color: #000000;
# }
# #T_9ba86_row2_col0 {
#   background-color: yellow;
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, orange 29.4%, orange 100.0%, transparent 100.0%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 29.4%, lightgreen 29.4%, lightgreen 100.0%, transparent 100.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #31D843;
#   color: white;
#   font-weight: bold;
#   color: #000000;
# }
# #T_9ba86_row2_col1 {
#   background-color: #a4bcda;
#   color: #000000;
#   background-color: #a4bcda;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, orange 20.4%, orange 38.0%, transparent 38.0%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 20.4%, lightgreen 20.4%, lightgreen 38.0%, transparent 38.0%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
#   color: #000000;
# }
# #T_9ba86_row2_col2 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   color: #dc3b2c;
#   background-color: #dc3b2c;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, orange 13.6%, transparent 13.6%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 13.6%, transparent 13.6%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
#   color: #000000;
# }
# #T_9ba86_row2_col3 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 14.3%, transparent 14.3%);
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 14.3%, transparent 14.3%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
#   color: #000000;
# }
# #T_9ba86_row3_col0 {
#   background-color: #f6eff7;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 5.9%, orange 5.9%, orange 29.4%, transparent 29.4%);
#   width: 10em;
#   background: linear-gradient(90deg, transparent 5.9%, red 5.9%, red 29.4%, transparent 29.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
#   color: #EE2E31;
# }
# #T_9ba86_row3_col1 {
#   background-color: yellow;
#   background-color: #fff7fb;
#   color: #000000;
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange 20.4%, transparent 20.4%);
#   width: 10em;
#   background: linear-gradient(90deg, red 20.4%, transparent 20.4%);
#   border: 1px solid black;
#   border: 2px solid gray;
#   color: green;
#   font-size: 16px;
#   border: 1px solid black;
#   width: 65px;
#   text-align: center;
#   background-color: #EE2E31;
#   color: white;
#   font-weight: bold;
#   color: #EE2E31;
# }
# #T_9ba86_row3_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
#   color: #7fc866;
#   background-color: #7fc866;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, orange

# %%
import openpyxl
df.background_gradient(cmap="RdYlGn").to_excel("table.xlsx")
